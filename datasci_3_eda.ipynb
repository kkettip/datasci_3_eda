# %% [markdown]
# <a href="https://colab.research.google.com/github/kkettip/datasci_3_eda/blob/main/datasci_3_eda.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
#Loading dataset

df = pd.read_json('https://data.cms.gov/data-api/v1/dataset/939226be-b107-476e-8777-f199a840138a/data')
df.sample(15)
# Out:
#      Year  quarter  Bene_Geo_Desc Bene_Mdcd_Mdcr_Enrl_Stus  \
# 945  2020        1   Pennsylvania                      All
# 885  2020        1           Ohio            Medicare Only
# 739  2020        1  New Hampshire                      All
# 900  2020        1       Oklahoma                      All
# 124  2020        1       Colorado      Medicare & Medicaid
# 571  2020        1       National                      All
# 451  2020        1  Massachusetts                      All
# 431  2020        1       Maryland                      All
# 556  2020        1        Montana                      All
# 370  2020        1       Kentucky                      All
# 656  2020        1       National                      All
# 232  2020        1         Hawaii                      All
# 733  2020        1         Nevada                      All
# 908  2020        1         Oregon                      All
# 402  2020        1          Maine                      All
#
# ...
